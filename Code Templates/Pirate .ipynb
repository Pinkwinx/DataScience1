# %%
pirateDataset = []
pirate1 = {
    "Name": "Blackbeard",
    "Sex": "Male",
    "Age of Death": 40,
    "Height": 6.4,
    "Skull and Crossbones": False
}
pirate2 = {
    "Name": "Anne Bonny",
    "Sex": "Female",
    "Age of Death": 24,
    "Height": 5.6,
    "Skull and Crossbones": True
}
pirate3 = {
    "Name": "Calico Jack",
    "Sex": "Male",
    "Age of Death": 37,
    "Height": 5.6,
    "Skull and Crossbones": True
}
pirate4 = {
    "Name": "Cheung Po Tsai",
    "Sex": "Male",
    "Age of Death": 39,
    "Height": 5.3,
    "Skull and Crossbones": False
}
pirate5 = {
    "Name": "Grace O'Malley",
    "Sex": "Female",
    "Age of Death": 73,
    "Height": 5.0,
    "Skull and Crossbones": False
}
pirate6 = {
    "Name": "Mary Read",
    "Sex": "Female",
    "Age of Death": 436,
    "Height": 5.1,
    "Skull and Crossbones": True
}
pirate7 = {
    "Name": "Sayyida al Hurra",
    "Sex": "Female",
    "Age of Death": 75,
    "Height": "unknown",
    "Skull and Crossbones": False
}
pirate8 = {
    "Name": "Ching Shih",
    "Sex": "Female",
    "Age of Death": 69,
    "Height": 5.3,
    "Skull and Crossbones": False
}
pirate9 = {
    "Name": "Sir Francis Drake",
    "Sex": "Male",
    "Age of Death": 56,
    "Height": 5.5,
    "Skull and Crossbones": False
}
pirate10 = {
    "Name": "Jean Lafitte",
    "Sex": "Male",
    "Age of Death": 46,
    "Height": 6.2,
    "Skull and Crossbones": False
}

pirateDataset.append(pirate1)
pirateDataset.append(pirate2)
pirateDataset.append(pirate3)
pirateDataset.append(pirate4)
pirateDataset.append(pirate5)
pirateDataset.append(pirate6)
pirateDataset.append(pirate7)
pirateDataset.append(pirate8)
pirateDataset.append(pirate9)
pirateDataset.append(pirate10)

for index, pirate in enumerate(pirateDataset, start=1):
    print(f"name: {pirate['Name']}")
    print(f"sex: {pirate['Sex']}")
    print(f"ageOfDeath: {pirate['Age of Death']}")
    print(f"height: {pirate['Height']}")
    print(f"skullAndCrossbones: {pirate['Skull and Crossbones']}")
    print("=" * 20)
# Out:
# name: Blackbeard
# sex: Male
# ageOfDeath: 40
# height: 6.4
# skullAndCrossbones: False
# ...
# name: Anne Bonny
# sex: Female
# ageOfDeath: 24
# height: 5.6
# skullAndCrossbones: True
# ...
# name: Calico Jack
# sex: Male
# ageOfDeath: 37
# height: 5.6
# skullAndCrossbones: True
# ...
# name: Cheung Po Tsai
# sex: Male
# ageOfDeath: 39
# height: 5.3
# skullAndCrossbones: False
# ...
# name: Grace O'Malley
# sex: Female
# ageOfDeath: 73
# height: 5.0
# skullAndCrossbones: False
# ...
# name: Mary Read
# sex: Female
# ageOfDeath: 436
# height: 5.1
# skullAndCrossbones: True
# ...
# name: Sayyida al Hurra
# sex: Female
# ageOfDeath: 75
# height: unknown
# skullAndCrossbones: False
# ...
# name: Ching Shih
# sex: Female
# ageOfDeath: 69
# height: 5.3
# skullAndCrossbones: False
# ...
# name: Sir Francis Drake
# sex: Male
# ageOfDeath: 56
# height: 5.5
# skullAndCrossbones: False
# ...
# name: Jean Lafitte
# sex: Male
# ageOfDeath: 46
# height: 6.2
# skullAndCrossbones: False
# ...

# %%
pirates = pirateDataset[1]  
print(f"name: {pirate['Name']}")
print(f"sex: {pirate['Sex']}")
print(f"ageOfDeath: {pirate['Age of Death']}")
print(f"height: {pirate['Height']}")
print(f"skullAndCrossbones: {pirate['Skull and Crossbones']}")
# Out:
# name: Jean Lafitte
# sex: Male
# ageOfDeath: 46
# height: 6.2
# skullAndCrossbones: False

# %%
skullAndCrossbones = [pirate['Skull and Crossbones'] for pirate in pirateDataset]
for skullAndCrossbones in ('Skull and Crossbones'):
    print(f"skullAndCrossbones: {pirate['Skull and Crossbones']}")
# Out:
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
# skullAndCrossbones: False
