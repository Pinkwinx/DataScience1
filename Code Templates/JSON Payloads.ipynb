# %%
import pandas as pd
import seaborn as sns
from io import StringIO

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNDUzZTQ4NzA4NTk5ODkwZGZjMWJhOTFlMDI5ZGJiNSIsInN1YiI6IjY1MWQ4OWI3MmYzYjE3MDBjN2Q5MDYyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Hu6no4jrRhsP2xmhfUirg6yQmbcYTAeJISNeMaMESm8"
}

response = requests.get(url, headers=headers)

# %%
response = response.json()
movie = response["results"][0]

# %%
movie
# Out:
# {'adult': False,
#  'backdrop_path': '/xFYpUmB01nswPgbzi8EOCT1ZYFu.jpg',
#  'genre_ids': [28, 18, 12],
#  'id': 980489,
#  'original_language': 'en',
#  'original_title': 'Gran Turismo',
#  'overview': 'The ultimate wish-fulfillment tale of a teenage Gran Turismo player whose gaming skills won him a series of Nissan competitions to become an actual professional racecar driver.',
#  'popularity': 3389.624,
#  'poster_path': '/51tqzRtKMMZEYUpSYkrUE7v9ehm.jpg',
#  'release_date': '2023-08-09',
#  'title': 'Gran Turismo',
#  'video': False,
#  'vote_average': 8,
#  'vote_count': 763}

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/xFYpUmB01nswPgbzi8EOCT1ZYFu.jpg',
#    'genre_ids': [28, 18, 12],
#    'id': 980489,
#    'original_language': 'en',
#    'original_title': 'Gran Turismo',
#    'overview': 'The ultimate wish-fulfillment tale of a teenage Gran Turismo player whose gaming skills won him a series of Nissan competitions to become an actual professional racecar driver.',
#    'popularity': 3389.624,
#    'poster_path': '/51tqzRtKMMZEYUpSYkrUE7v9ehm.jpg',
#    'release_date': '2023-08-09',
#    'title': 'Gran Turismo',
#    'video': False,
#    'vote_average': 8,
#    'vote_count': 763},
#   {'adult': False,
#    'backdrop_path': '/1syW9SNna38rSl9fnXwc9fP7POW.jpg',
#    'genre_ids': [28, 878, 12],
#    'id': 565770,
#    'original_language': 'en',
#    'original_title': 'Blue Beetle',
# ...

# %%
df = pd.DataFrame(response)

# %%
df.head()
# Out:
#    page                                            results  total_pages  \
# 0     1  {'adult': False, 'backdrop_path': '/xFYpUmB01n...        40353
# 1     1  {'adult': False, 'backdrop_path': '/1syW9SNna3...        40353
# 2     1  {'adult': False, 'backdrop_path': '/pA3vdhadJP...        40353
# 3     1  {'adult': False, 'backdrop_path': '/mRGmNnh6pB...        40353
# 4     1  {'adult': False, 'backdrop_path': '/8pjWz2lt29...        40353
#
#    total_results
# 0         807055
# 1         807055
# 2         807055
# 3         807055
# 4         807055

# %%
# Replace 'YOUR_API_KEY' with your actual TMDb API key
api_key = '1453e48708599890dfc1ba91e029dbb5'
anime_title = 'Jujutsu Kaisen'

# Create the API request URL
url = f'https://api.themoviedb.org/3/search/tv?api_key={api_key}&query={anime_title}&language=en-US'

# Make the request
response = requests.get(url)

# Parse the JSON response
data = response.json()

# Extract information about the anime
anime_data = data['results'][0]  # Assuming the first result is the correct anime

# %%
global_popularity = anime_data['popularity']  # Global popularity score
japan_popularity = anime_data['vote_average']  # Japan's popularity score (vote_average is used here)

# Print the popularity scores
print(f'Global Popularity: {global_popularity}')
print(f'Japan Popularity: {japan_popularity}')
# Out:
# Global Popularity: 578.14
# Japan Popularity: 8.565
